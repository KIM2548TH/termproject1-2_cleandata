# %%
import pandas as pd
import matplotlib.pyplot as plt

# อ่านข้อมูลจากไฟล์ CSV
df = pd.read_csv('province/data_eng_day.csv')

# แปลงคอลัมน์ timestamp ให้เป็นวันที่โดยเอาเวลาออก
df['timestamp'] = pd.to_datetime(df['timestamp']).dt.date

# ตั้งค่าแกน x และ y
x = df['timestamp']
y_columns = ['humidity', 'pm_10', 'pm_2_5', 'temperature']

# พลอตกราฟเส้นที่มีจุด
plt.figure(figsize=(10, 6))
for column in y_columns:
    plt.plot(x, df[column], marker='o', label=column)

# ตั้งค่าชื่อแกนและชื่อกราฟ
plt.xlabel('Date')
plt.ylabel('Values')
plt.title('Time Series Data')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()

# แสดงกราฟ
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# อ่านข้อมูลจากไฟล์ CSV
df = pd.read_csv('province/data_eng_hour.csv')



# ตั้งค่าแกน x และ y
x = df['timestamp']
y_columns = ['humidity', 'pm_10', 'pm_2_5', 'temperature']

# พลอตกราฟเส้นที่มีจุด
plt.figure(figsize=(10, 6))
for column in y_columns:
    plt.plot(x, df[column], marker='o', label=column)

# ตั้งค่าชื่อแกนและชื่อกราฟ
plt.xlabel('Date')
plt.ylabel('Values')
plt.title('Time Series Data')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()

# แสดงกราฟ
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# อ่านข้อมูลจากไฟล์ CSV
df = pd.read_csv('province/data_eng_day.csv')

# แปลงคอลัมน์ timestamp ให้เป็นวันที่โดยเอาเวลาออก
df['timestamp'] = pd.to_datetime(df['timestamp']).dt.date

# ฟังก์ชันเพื่อกำหนดฤดูกาลตามวันที่
def get_season(date):
    if date.month in [12, 1, 2]:
        return 'Winter'
    elif date.month in [3, 4, 5]:
        return 'Spring'
    elif date.month in [6, 7, 8]:
        return 'Summer'
    elif date.month in [9, 10, 11]:
        return 'Autumn'

# เพิ่มคอลัมน์ season ลงใน DataFrame
df['season'] = df['timestamp'].apply(get_season)

# ตั้งค่าแกน x และ y
x = df['timestamp']
y_columns = ['humidity', 'pm_10', 'pm_2_5', 'temperature']

# พลอตกราฟเส้นที่มีจุด
plt.figure(figsize=(10, 6))
for column in y_columns:
    plt.plot(x, df[column], marker='o', label=column)

# ตั้งค่าชื่อแกนและชื่อกราฟ
plt.xlabel('Date')
plt.ylabel('Values')
plt.title('Time Series Data')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()

# แสดงกราฟ
plt.show()

# แสดง DataFrame ที่มีคอลัมน์ season
print(df)
# Out:
#      Unnamed: 0   timestamp      timezone   humidity      pm_10     pm_2_5  \
# 0             0  2023-04-01  Asia/Bangkok  73.861694   4.727273   4.727273
# 1             1  2023-04-03  Asia/Bangkok  67.872493  16.046366  14.585213
# 2             2  2023-04-04  Asia/Bangkok  62.995952  13.300139  11.938022
# 3             3  2023-04-05  Asia/Bangkok  59.482051  11.864336  10.733566
# 4             4  2023-04-06  Asia/Bangkok  66.493574  16.405837  14.758860
# ..          ...         ...           ...        ...        ...        ...
# 658         658  2025-02-08  Asia/Bangkok  69.348548  30.654249  26.000000
# 659         659  2025-02-09  Asia/Bangkok  69.916384  28.971065  24.616898
# 660         660  2025-02-10  Asia/Bangkok  71.226336  30.652667  25.856981
# 661         661  2025-02-11  Asia/Bangkok  68.159624  32.532955  27.522727
# 662         662  2025-02-11  Asia/Bangkok  76.329751  33.787755  29.587755
#
#      pm_2_5_sp  temperature  season
# 0     4.727273    30.189449  Spring
# 1    14.699248    29.895143  Spring
# 2    11.942897    33.853401  Spring
# 3    10.733566    35.772219  Spring
# 4    14.840167    31.862498  Spring
# ..         ...          ...     ...
# 658  22.380675    28.385596  Winter
# 659  20.976852    28.373742  Winter
# 660  22.374574    28.251201  Winter
# 661  24.120455    28.693799  Winter
# 662  27.918367    27.633866  Winter
#
# [663 rows x 9 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# อ่านข้อมูลจากไฟล์ CSV
df = pd.read_csv('province/data_eng_day.csv')

# ลบคอลัมน์ที่ไม่มีชื่อ (Unnamed)
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]

# แปลงคอลัมน์ timestamp ให้เป็นวันที่โดยเอาเวลาออก
df['timestamp'] = pd.to_datetime(df['timestamp']).dt.date

# ฟังก์ชันเพื่อกำหนดฤดูกาลตามวันที่
def get_season(date):
    if date.month in [12, 1, 2]:
        return 'Winter'
    elif date.month in [3, 4, 5]:
        return 'Spring'
    elif date.month in [6, 7, 8]:
        return 'Summer'
    elif date.month in [9, 10, 11]:
        return 'Autumn'

# เพิ่มคอลัมน์ season ลงใน DataFrame
df['season'] = df['timestamp'].apply(get_season)

# สร้างคอลัมน์ใหม่สำหรับแต่ละฤดูกาล
df['Winter'] = df['season'].apply(lambda x: 1 if x == 'Winter' else 0)
df['Spring'] = df['season'].apply(lambda x: 1 if x == 'Spring' else 0)
df['Summer'] = df['season'].apply(lambda x: 1 if x == 'Summer' else 0)
df['Autumn'] = df['season'].apply(lambda x: 1 if x == 'Autumn' else 0)

# ตั้งค่าแกน x และ y
x = df['timestamp']
y_columns = ['humidity', 'pm_10', 'pm_2_5', 'temperature']

# พลอตกราฟเส้นที่มีจุด
plt.figure(figsize=(10, 6))
for column in y_columns:
    plt.plot(x, df[column], marker='o', label=column)

# ตั้งค่าชื่อแกนและชื่อกราฟ
plt.xlabel('Date')
plt.ylabel('Values')
plt.title('Time Series Data')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()

# แสดงกราฟ
plt.show()

# แสดง DataFrame ที่มีคอลัมน์ season และฤดูกาล
print(df)
# Out:
#       timestamp      timezone   humidity      pm_10     pm_2_5  pm_2_5_sp  \
# 0    2023-04-01  Asia/Bangkok  73.861694   4.727273   4.727273   4.727273
# 1    2023-04-03  Asia/Bangkok  67.872493  16.046366  14.585213  14.699248
# 2    2023-04-04  Asia/Bangkok  62.995952  13.300139  11.938022  11.942897
# 3    2023-04-05  Asia/Bangkok  59.482051  11.864336  10.733566  10.733566
# 4    2023-04-06  Asia/Bangkok  66.493574  16.405837  14.758860  14.840167
# ..          ...           ...        ...        ...        ...        ...
# 658  2025-02-08  Asia/Bangkok  69.348548  30.654249  26.000000  22.380675
# 659  2025-02-09  Asia/Bangkok  69.916384  28.971065  24.616898  20.976852
# 660  2025-02-10  Asia/Bangkok  71.226336  30.652667  25.856981  22.374574
# 661  2025-02-11  Asia/Bangkok  68.159624  32.532955  27.522727  24.120455
# 662  2025-02-11  Asia/Bangkok  76.329751  33.787755  29.587755  27.918367
#
#      temperature  season  Winter  Spring  Summer  Autumn
# 0      30.189449  Spring       0       1       0       0
# 1      29.895143  Spring       0       1       0       0
# 2      33.853401  Spring       0       1       0       0
# 3      35.772219  Spring       0       1       0       0
# 4      31.862498  Spring       0       1       0       0
# ..           ...     ...     ...     ...     ...     ...
# 658    28.385596  Winter       1       0       0       0
# 659    28.373742  Winter       1       0       0       0
# 660    28.251201  Winter       1       0       0       0
# 661    28.693799  Winter       1       0       0       0
# 662    27.633866  Winter       1       0       0       0
#
# [663 rows x 12 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# อ่านข้อมูลจากไฟล์ CSV
df = pd.read_csv('province/data_eng_day.csv')

# ลบคอลัมน์ที่ไม่มีชื่อ (Unnamed)
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]

# แปลงคอลัมน์ timestamp ให้เป็นวันที่โดยเอาเวลาออก
df['timestamp'] = pd.to_datetime(df['timestamp']).dt.date

# ฟังก์ชันเพื่อกำหนดฤดูกาลตามวันที่
def get_season(date):
    if date.month in [5, 6, 7, 8, 9, 10]:
        return 'Rainy'
    else:
        return 'Summer'

# เพิ่มคอลัมน์ season ลงใน DataFrame
df['season'] = df['timestamp'].apply(get_season)

# ตรวจสอบคอลัมน์ใน DataFrame
print(df.columns)

# ตรวจสอบข้อมูลในคอลัมน์ season
print(df['season'].unique())

# ตรวจสอบข้อมูลใน DataFrame
print(df.head())

# สร้างคอลัมน์ใหม่สำหรับแต่ละฤดูกาล
df['Rainy'] = df['season'].apply(lambda x: 1 if x == 'Rainy' else 0)
df['Summer'] = df['season'].apply(lambda x: 1 if x == 'Summer' else 0)

# เลือกเฉพาะคอลัมน์ที่เป็นตัวเลข
numeric_columns = df.select_dtypes(include=['number']).columns

# แสดงกราฟตามฤดูกาล
seasonal_data = df.groupby('season')[numeric_columns].mean()

# ตรวจสอบข้อมูลใน seasonal_data
print(seasonal_data)

# พลอตกราฟแสดงข้อมูลตามฤดูกาล
y_columns = ['humidity', 'pm_10', 'pm_2_5', 'temperature']
seasonal_data[y_columns].plot(kind='bar', figsize=(10, 6))
plt.xlabel('Season')
plt.ylabel('Average Values')
plt.title('Average Values by Season')
plt.legend()
plt.grid(True)
plt.tight_layout()

# แสดงกราฟ
plt.show()
# Out:
# Index(['timestamp', 'timezone', 'humidity', 'pm_10', 'pm_2_5', 'pm_2_5_sp',
#        'temperature', 'season'],
#       dtype='object')
# ['Summer' 'Rainy']
#     timestamp      timezone   humidity      pm_10     pm_2_5  pm_2_5_sp  \
# 0  2023-04-01  Asia/Bangkok  73.861694   4.727273   4.727273   4.727273
# 1  2023-04-03  Asia/Bangkok  67.872493  16.046366  14.585213  14.699248
# 2  2023-04-04  Asia/Bangkok  62.995952  13.300139  11.938022  11.942897
# 3  2023-04-05  Asia/Bangkok  59.482051  11.864336  10.733566  10.733566
# 4  2023-04-06  Asia/Bangkok  66.493574  16.405837  14.758860  14.840167
#
#    temperature  season
# 0    30.189449  Summer
# 1    29.895143  Summer
# 2    33.853401  Summer
# 3    35.772219  Summer
# 4    31.862498  Summer
#          humidity      pm_10     pm_2_5  pm_2_5_sp  temperature  Rainy  Summer
# season
# Rainy   76.724421  23.970809  21.029305  19.971963    30.434393    1.0     0.0
# Summer  80.509005  24.528249  21.110773  19.223860    28.654806    0.0     1.0

# %%
import pandas as pd
import matplotlib.pyplot as plt

# อ่านข้อมูลจากไฟล์ CSV
df = pd.read_csv('province/data_eng_hour.csv')

# แปลงคอลัมน์ timestamp ให้เป็น datetime
df['timestamp'] = pd.to_datetime(df['timestamp'])

# ตั้งค่าแกน x และ y
x = df['timestamp']
y_columns = ['humidity', 'pm_10', 'pm_2_5', 'temperature']

# พลอตกราฟเส้นที่มีจุด
plt.figure(figsize=(12, 8))
for column in y_columns:
    plt.plot_date(x, df[column], marker='o', linestyle='-', label=column, markersize=4)

# ตั้งค่าชื่อแกนและชื่อกราฟ
plt.xlabel('Date')
plt.ylabel('Values')
plt.title('Time Series Data')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()

# แสดงกราฟ
plt.show()
# Out:
# /var/folders/x_/lq083y1j115fh3cygnc627p00000gn/T/ipykernel_11362/302892164.py:17: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   plt.plot_date(x, df[column], marker='o', linestyle='-', label=column, markersize=4)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# อ่านข้อมูลจากไฟล์ CSV
df = pd.read_csv('daily_csv/export-jsps014-1d.csv')

# แปลงคอลัมน์ timestamp ให้เป็นวันที่โดยเอาเวลาออก
df['timestamp'] = pd.to_datetime(df['timestamp']).dt.date

# ตั้งค่าแกน x และ y
x = df['timestamp']
y_columns = ['humidity', 'pm_2_5', 'temperature']

# พลอตกราฟเส้นที่มีจุด
plt.figure(figsize=(10, 6))
for column in y_columns:
    plt.plot(x, df[column], marker='o', label=column)

# ตั้งค่าชื่อแกนและชื่อกราฟ
plt.xlabel('Date')
plt.ylabel('Values')
plt.title('Time Series Data')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()

# แสดงกราฟ
plt.show()

# %%
import pandas as pd

# อ่านไฟล์ CSV
df = pd.read_csv('daily_csv/export-jsps014-1d.csv')

# ฟังก์ชันเพื่อกำหนดฤดูกาลตามวันที่
def get_season(date):
    month = date.month
    if month >= 5 and month <= 10:
        return 'rainy'
    else:
        return 'summer'

# แปลงคอลัมน์ timestamp เป็น datetime
df['timestamp'] = pd.to_datetime(df['timestamp'])

# สร้างคอลัมน์ฤดูกาล
df['season'] = df['timestamp'].apply(get_season)

# แยกคอลัมน์ฤดูกาลเป็น 2 คอลัมน์ (rainy และ summer)
df['rainy'] = df['season'].apply(lambda x: 1 if x == 'rainy' else 0)
df['summer'] = df['season'].apply(lambda x: 1 if x == 'summer' else 0)

# แสดง DataFrame ใน Jupyter Notebook
print(df)
# Out:
#       Unnamed: 0               timestamp      timezone   humidity     pm_2_5  \
# 0              0 2022-03-18 07:00:00.000  Asia/Bangkok  71.447328  16.494085
# 1              1 2022-03-19 07:00:00.000  Asia/Bangkok  57.655222  12.481085
# 2              2 2022-03-20 07:00:00.000  Asia/Bangkok  70.612702  11.406250
# 3              3 2022-03-21 07:00:00.000  Asia/Bangkok  75.826971  19.382453
# 4              4 2022-03-22 07:00:00.000  Asia/Bangkok  62.571896   9.946089
# ...          ...                     ...           ...        ...        ...
# 1040        1040 2025-02-08 07:00:00.000  Asia/Bangkok  65.974686  19.064854
# 1041        1041 2025-02-09 07:00:00.000  Asia/Bangkok  66.850779  13.824501
# 1042        1042 2025-02-10 07:00:00.000  Asia/Bangkok  67.651647  18.744632
# 1043        1043 2025-02-11 07:00:00.000  Asia/Bangkok  66.932706  25.979693
# 1044        1044 2025-02-11 11:12:50.717  Asia/Bangkok  78.569690  27.760396
#
#       pm_2_5_sp  temperature                location  season  rainy  summer
# 0     16.929715    28.747286  export-jsps014-1d.xlsx  summer      0       1
# 1     12.669469    31.958980  export-jsps014-1d.xlsx  summer      0       1
# 2     11.519928    29.220503  export-jsps014-1d.xlsx  summer      0       1
# 3     20.238501    28.088548  export-jsps014-1d.xlsx  summer      0       1
# 4     10.170190    30.740634  export-jsps014-1d.xlsx  summer      0       1
# ...         ...          ...                     ...     ...    ...     ...
# 1040  19.214784    29.716301  export-jsps014-1d.xlsx  summer      0       1
# 1041  13.928955    29.145664  export-jsps014-1d.xlsx  summer      0       1
# 1042  19.580015    29.690582  export-jsps014-1d.xlsx  summer      0       1
# 1043  28.870115    29.804851  export-jsps014-1d.xlsx  summer      0       1
# 1044  32.736634    28.326317  export-jsps014-1d.xlsx  summer      0       1
#
# [1045 rows x 11 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# อ่านไฟล์ CSV
df = pd.read_csv('daily_csv/export-jsps014-1d.csv')

# ลบคอลัมน์ที่ไม่ต้องการ (Unnamed)
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]

# ฟังก์ชันเพื่อกำหนดฤดูกาลตามวันที่
def get_season(date):
    month = date.month
    if month >= 5 and month <= 10:
        return 'rainy'
    else:
        return 'summer'

# แปลงคอลัมน์ timestamp เป็น datetime
df['timestamp'] = pd.to_datetime(df['timestamp'])

# สร้างคอลัมน์ฤดูกาล
df['season'] = df['timestamp'].apply(get_season)

# แยกคอลัมน์ฤดูกาลเป็น 2 คอลัมน์ (rainy และ summer)
df['rainy'] = df['season'].apply(lambda x: 1 if x == 'rainy' else 0)
df['summer'] = df['season'].apply(lambda x: 1 if x == 'summer' else 0)

# แสดง DataFrame ใน Jupyter Notebook
print(df)

# พล้อตกราฟเส้นที่มีแกน x เป็น timestamp สำหรับทุกคอลัมน์
plt.figure(figsize=(14, 7))
for column in df.columns:
    if column != 'timestamp':
        plt.plot(df['timestamp'], df[column], label=column)

plt.xlabel('Timestamp')
plt.ylabel('Values')
plt.title('Time Series Data')
plt.legend()
plt.show()
# Out:
#                    timestamp      timezone   humidity     pm_2_5  pm_2_5_sp  \
# 0    2022-03-18 07:00:00.000  Asia/Bangkok  71.447328  16.494085  16.929715
# 1    2022-03-19 07:00:00.000  Asia/Bangkok  57.655222  12.481085  12.669469
# 2    2022-03-20 07:00:00.000  Asia/Bangkok  70.612702  11.406250  11.519928
# 3    2022-03-21 07:00:00.000  Asia/Bangkok  75.826971  19.382453  20.238501
# 4    2022-03-22 07:00:00.000  Asia/Bangkok  62.571896   9.946089  10.170190
# ...                      ...           ...        ...        ...        ...
# 1040 2025-02-08 07:00:00.000  Asia/Bangkok  65.974686  19.064854  19.214784
# 1041 2025-02-09 07:00:00.000  Asia/Bangkok  66.850779  13.824501  13.928955
# 1042 2025-02-10 07:00:00.000  Asia/Bangkok  67.651647  18.744632  19.580015
# 1043 2025-02-11 07:00:00.000  Asia/Bangkok  66.932706  25.979693  28.870115
# 1044 2025-02-11 11:12:50.717  Asia/Bangkok  78.569690  27.760396  32.736634
#
#       temperature                location  season  rainy  summer
# 0       28.747286  export-jsps014-1d.xlsx  summer      0       1
# 1       31.958980  export-jsps014-1d.xlsx  summer      0       1
# 2       29.220503  export-jsps014-1d.xlsx  summer      0       1
# 3       28.088548  export-jsps014-1d.xlsx  summer      0       1
# 4       30.740634  export-jsps014-1d.xlsx  summer      0       1
# ...           ...                     ...     ...    ...     ...
# 1040    29.716301  export-jsps014-1d.xlsx  summer      0       1
# 1041    29.145664  export-jsps014-1d.xlsx  summer      0       1
# 1042    29.690582  export-jsps014-1d.xlsx  summer      0       1
# 1043    29.804851  export-jsps014-1d.xlsx  summer      0       1
# 1044    28.326317  export-jsps014-1d.xlsx  summer      0       1
#
# [1045 rows x 10 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

# อ่านไฟล์ CSV
df = pd.read_csv('daily_csv/export-jsps014-1d.csv')

# ลบคอลัมน์ที่ไม่ต้องการ (Unnamed)
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]

# แปลงคอลัมน์ timestamp เป็น datetime
df['timestamp'] = pd.to_datetime(df['timestamp'])

# สร้างคอลัมน์ฤดูกาล
def get_season(date):
    month = date.month
    if month >= 5 and month <= 10:
        return 'rainy'
    else:
        return 'summer'

df['season'] = df['timestamp'].apply(get_season)

# แยกคอลัมน์ฤดูกาลเป็น 2 คอลัมน์ (rainy และ summer)
df['rainy'] = df['season'].apply(lambda x: 1 if x == 'rainy' else 0)
df['summer'] = df['season'].apply(lambda x: 1 if x == 'summer' else 0)

# Deseasonalization
df.set_index('timestamp', inplace=True)
result = seasonal_decompose(df['pm_2_5'], model='additive', period=365)
deseasonalized = df['pm_2_5'] - result.seasonal

# Detrending
deseasonalized_diff = deseasonalized.diff().dropna()

# การใช้ฟีเจอร์เสริม (Exogenous Features)
exog_features = df[['rainy', 'summer']].loc[deseasonalized_diff.index]

# การเลือกโมเดลที่เหมาะสม
model = SARIMAX(deseasonalized_diff, exog=exog_features, order=(1, 1, 1), seasonal_order=(1, 1, 1, 12))
results = model.fit()

# ตรวจสอบว่าดัชนีมีค่า '2022-01-01' หรือไม่
if pd.to_datetime('2022-01-01') in deseasonalized_diff.index:
    start_date = pd.to_datetime('2022-01-01')
else:
    start_date = deseasonalized_diff.index[0]

# ประเมินผลและการทำนาย
pred = results.get_prediction(start=start_date, dynamic=False)
pred_ci = pred.conf_int()

# การแสดงผลข้อมูล
ax = deseasonalized_diff['2021':].plot(label='Observed')
pred.predicted_mean.plot(ax=ax, label='Forecast', alpha=.7, figsize=(14, 7))
ax.fill_between(pred_ci.index, pred_ci.iloc[:, 0], pred_ci.iloc[:, 1], color='k', alpha=.2)
ax.set_xlabel('Date')
ax.set_ylabel('pm_2_5')
plt.legend()
plt.show()

# ประเมินผล
y_forecasted = pred.predicted_mean
y_truth = deseasonalized_diff[start_date:]
mse = mean_squared_error(y_truth, y_forecasted)
print(f'The Mean Squared Error of our forecasts is {mse}')
# Out:
# /Users/pittachiox/Desktop/termproject/venv/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /Users/pittachiox/Desktop/termproject/venv/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.51695D+00    |proj g|=  1.00267D-01
#
# At iterate    5    f=  3.27022D+00    |proj g|=  8.56532D-02
#
# At iterate   10    f=  3.25887D+00    |proj g|=  3.61184D-02
#
# At iterate   15    f=  3.24873D+00    |proj g|=  1.83499D-02
#
# At iterate   20    f=  3.24742D+00    |proj g|=  2.92287D-03
#
# At iterate   25    f=  3.24732D+00    |proj g|=  5.90934D-04
#
# At iterate   30    f=  3.24731D+00    |proj g|=  2.61301D-04
#
# At iterate   35    f=  3.24731D+00    |proj g|=  5.98232D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     35     46      1     0     0   5.982D-05   3.247D+00
#   F =   3.2473130211360575
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# The Mean Squared Error of our forecasts is 44.11482785870934

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.metrics import mean_absolute_error, mean_squared_error
import numpy as np

# อ่านไฟล์ CSV
df = pd.read_csv('daily_csv/export-jsps014-1d.csv')

# ลบคอลัมน์ที่ไม่ต้องการ (Unnamed)
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]

# แปลงคอลัมน์ timestamp เป็น datetime
df['timestamp'] = pd.to_datetime(df['timestamp'])

# สร้างคอลัมน์ฤดูกาล
def get_season(date):
    month = date.month
    if month >= 5 and month <= 10:
        return 'rainy'
    else:
        return 'summer'

df['season'] = df['timestamp'].apply(get_season)

# แยกคอลัมน์ฤดูกาลเป็น 2 คอลัมน์ (rainy และ summer)
df['rainy'] = df['season'].apply(lambda x: 1 if x == 'rainy' else 0)
df['summer'] = df['season'].apply(lambda x: 1 if x == 'summer' else 0)

# Deseasonalization
df.set_index('timestamp', inplace=True)
result = seasonal_decompose(df['pm_2_5'], model='additive', period=365)
deseasonalized = df['pm_2_5'] - result.seasonal

# Detrending
deseasonalized_diff = deseasonalized.diff().dropna()

# การใช้ฟีเจอร์เสริม (Exogenous Features)
exog_features = df[['rainy', 'summer']].loc[deseasonalized_diff.index]

# การเลือกโมเดลที่เหมาะสม
model = SARIMAX(deseasonalized_diff, exog=exog_features, order=(1, 1, 1), seasonal_order=(1, 1, 1, 12))
results = model.fit()

# ตรวจสอบว่าดัชนีมีค่า '2022-01-01' หรือไม่
if pd.to_datetime('2022-01-01') in deseasonalized_diff.index:
    start_date = pd.to_datetime('2022-01-01')
else:
    start_date = deseasonalized_diff.index[0]

# ประเมินผลและการทำนาย
pred = results.get_prediction(start=start_date, dynamic=False)
pred_ci = pred.conf_int()

# การแสดงผลข้อมูล
ax = deseasonalized_diff['2021':].plot(label='Observed')
pred.predicted_mean.plot(ax=ax, label='Forecast', alpha=.7, figsize=(14, 7))
ax.fill_between(pred_ci.index, pred_ci.iloc[:, 0], pred_ci.iloc[:, 1], color='k', alpha=.2)
ax.set_xlabel('Date')
ax.set_ylabel('pm_2_5')
plt.legend()
plt.show()

# ประเมินผล
y_forecasted = pred.predicted_mean
y_truth = deseasonalized_diff[start_date:]
mse = mean_squared_error(y_truth, y_forecasted)
print(f'The Mean Squared Error of our forecasts is {mse}')
# Out:
# /Users/pittachiox/Desktop/termproject/venv/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# /Users/pittachiox/Desktop/termproject/venv/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            7     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.51695D+00    |proj g|=  1.00267D-01
#
# At iterate    5    f=  3.27022D+00    |proj g|=  8.56532D-02
#
# At iterate   10    f=  3.25887D+00    |proj g|=  3.61184D-02
#
# At iterate   15    f=  3.24873D+00    |proj g|=  1.83499D-02
#
# At iterate   20    f=  3.24742D+00    |proj g|=  2.92287D-03
#
# At iterate   25    f=  3.24732D+00    |proj g|=  5.90934D-04
#
# At iterate   30    f=  3.24731D+00    |proj g|=  2.61301D-04
#
# At iterate   35    f=  3.24731D+00    |proj g|=  5.98232D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     7     35     46      1     0     0   5.982D-05   3.247D+00
#   F =   3.2473130211360575
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# The Mean Squared Error of our forecasts is 44.11482785870934

# %%
import pandas as pd
import matplotlib.pyplot as plt

# อ่านข้อมูลจากไฟล์ CSV
df = pd.read_csv('province/data_eng_day.csv')

# ลบคอลัมน์ที่ไม่มีชื่อ (Unnamed)
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]

# แปลงคอลัมน์ timestamp ให้เป็นวันที่โดยเอาเวลาออก
df['timestamp'] = pd.to_datetime(df['timestamp']).dt.date

# ฟังก์ชันเพื่อกำหนดฤดูกาลตามวันที่
def get_season(date):
    if date.month in [12, 1, 2]:
        return 'Winter'
    elif date.month in [3, 4, 5]:
        return 'Spring'
    elif date.month in [6, 7, 8]:
        return 'Summer'
    elif date.month in [9, 10, 11]:
        return 'Autumn'

# เพิ่มคอลัมน์ season ลงใน DataFrame
df['season'] = df['timestamp'].apply(get_season)

# สร้างคอลัมน์ใหม่สำหรับแต่ละฤดูกาล
df['Winter'] = df['season'].apply(lambda x: 1 if x == 'Winter' else 0)
df['Spring'] = df['season'].apply(lambda x: 1 if x == 'Spring' else 0)
df['Summer'] = df['season'].apply(lambda x: 1 if x == 'Summer' else 0)
df['Autumn'] = df['season'].apply(lambda x: 1 if x == 'Autumn' else 0)

# กำหนดเกณฑ์สำหรับค่า pm_10 และ humidity
df
# Out:
#       timestamp      timezone   humidity      pm_10     pm_2_5  pm_2_5_sp  \
# 0    2023-04-01  Asia/Bangkok  73.861694   4.727273   4.727273   4.727273
# 1    2023-04-03  Asia/Bangkok  67.872493  16.046366  14.585213  14.699248
# 2    2023-04-04  Asia/Bangkok  62.995952  13.300139  11.938022  11.942897
# 3    2023-04-05  Asia/Bangkok  59.482051  11.864336  10.733566  10.733566
# 4    2023-04-06  Asia/Bangkok  66.493574  16.405837  14.758860  14.840167
# ..          ...           ...        ...        ...        ...        ...
# 658  2025-02-08  Asia/Bangkok  69.348548  30.654249  26.000000  22.380675
# 659  2025-02-09  Asia/Bangkok  69.916384  28.971065  24.616898  20.976852
# 660  2025-02-10  Asia/Bangkok  71.226336  30.652667  25.856981  22.374574
# 661  2025-02-11  Asia/Bangkok  68.159624  32.532955  27.522727  24.120455
# 662  2025-02-11  Asia/Bangkok  76.329751  33.787755  29.587755  27.918367
#
#      temperature  season  Winter  Spring  Summer  Autumn
# 0      30.189449  Spring       0       1       0       0
# 1      29.895143  Spring       0       1       0       0
# 2      33.853401  Spring       0       1       0       0
# 3      35.772219  Spring       0       1       0       0
# 4      31.862498  Spring       0       1       0       0
# ..           ...     ...     ...     ...     ...     ...
# 658    28.385596  Winter       1       0       0       0
# 659    28.373742  Winter       1       0       0       0
# 660    28.251201  Winter       1       0       0       0
# 661    28.693799  Winter       1       0       0       0
# 662    27.633866  Winter       1       0       0       0
#
# [663 rows x 12 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# อ่านข้อมูลจากไฟล์ CSV
df = pd.read_csv('province/data_eng_day.csv')

# ลบคอลัมน์ที่ไม่มีชื่อ (Unnamed)
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]

# แปลงคอลัมน์ timestamp ให้เป็นวันที่โดยเอาเวลาออก
df['timestamp'] = pd.to_datetime(df['timestamp']).dt.date

# ฟังก์ชันเพื่อกำหนดฤดูกาลตามวันที่
def get_season(date):
    if date.month in [12, 1, 2]:
        return 'Winter'
    elif date.month in [3, 4, 5]:
        return 'Spring'
    elif date.month in [6, 7, 8]:
        return 'Summer'
    elif date.month in [9, 10, 11]:
        return 'Autumn'

# เพิ่มคอลัมน์ season ลงใน DataFrame
df['season'] = df['timestamp'].apply(get_season)

# สร้างคอลัมน์ใหม่สำหรับแต่ละฤดูกาล
df['Winter'] = df['season'].apply(lambda x: 1 if x == 'Winter' else 0)
df['Spring'] = df['season'].apply(lambda x: 1 if x == 'Spring' else 0)
df['Summer'] = df['season'].apply(lambda x: 1 if x == 'Summer' else 0)
df['Autumn'] = df['season'].apply(lambda x: 1 if x == 'Autumn' else 0)

# กำหนดเกณฑ์สำหรับค่า pm_10 และ humidity
df = df[(df['pm_10'] >= 0) & (df['pm_10'] <= 55)]
df = df[(df['humidity'] >= 0) & (df['humidity'] <= 100)]

# ตั้งค่าแกน x และ y
x = df['timestamp']
y_columns = ['humidity', 'pm_10', 'pm_2_5', 'temperature']

# พลอตกราฟเส้นที่มีจุด
plt.figure(figsize=(10, 6))
for column in y_columns:
    plt.plot(x, df[column], marker='o', label=column)

# ตั้งค่าชื่อแกนและชื่อกราฟ
plt.xlabel('Date')
plt.ylabel('Values')
plt.title('Time Series Data')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()

# แสดงกราฟ
plt.show()

# แสดง DataFrame ที่มีคอลัมน์ season และฤดูกาล
print(df)
# Out:
#       timestamp      timezone   humidity      pm_10     pm_2_5  pm_2_5_sp  \
# 0    2023-04-01  Asia/Bangkok  73.861694   4.727273   4.727273   4.727273
# 1    2023-04-03  Asia/Bangkok  67.872493  16.046366  14.585213  14.699248
# 2    2023-04-04  Asia/Bangkok  62.995952  13.300139  11.938022  11.942897
# 3    2023-04-05  Asia/Bangkok  59.482051  11.864336  10.733566  10.733566
# 4    2023-04-06  Asia/Bangkok  66.493574  16.405837  14.758860  14.840167
# ..          ...           ...        ...        ...        ...        ...
# 658  2025-02-08  Asia/Bangkok  69.348548  30.654249  26.000000  22.380675
# 659  2025-02-09  Asia/Bangkok  69.916384  28.971065  24.616898  20.976852
# 660  2025-02-10  Asia/Bangkok  71.226336  30.652667  25.856981  22.374574
# 661  2025-02-11  Asia/Bangkok  68.159624  32.532955  27.522727  24.120455
# 662  2025-02-11  Asia/Bangkok  76.329751  33.787755  29.587755  27.918367
#
#      temperature  season  Winter  Spring  Summer  Autumn
# 0      30.189449  Spring       0       1       0       0
# 1      29.895143  Spring       0       1       0       0
# 2      33.853401  Spring       0       1       0       0
# 3      35.772219  Spring       0       1       0       0
# 4      31.862498  Spring       0       1       0       0
# ..           ...     ...     ...     ...     ...     ...
# 658    28.385596  Winter       1       0       0       0
# 659    28.373742  Winter       1       0       0       0
# 660    28.251201  Winter       1       0       0       0
# 661    28.693799  Winter       1       0       0       0
# 662    27.633866  Winter       1       0       0       0
#
# [655 rows x 12 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# อ่านข้อมูลจากไฟล์ CSV
df = pd.read_csv('province/data_eng_hour.csv')

# กำหนดเกณฑ์สำหรับค่า pm_10
df = df[(df['pm_10'] >= 0) & (df['pm_10'] <= 80)]

# ตั้งค่าแกน x และ y
x = df['timestamp']
y_columns = ['humidity', 'pm_10', 'pm_2_5', 'temperature']

# พลอตกราฟเส้นที่มีจุด
plt.figure(figsize=(10, 6))
for column in y_columns:
    plt.plot(x, df[column], marker='o', label=column)

# ตั้งค่าชื่อแกนและชื่อกราฟ
plt.xlabel('Date')
plt.ylabel('Values')
plt.title('Time Series Data')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()

# แสดงกราฟ
plt.show()
print(df.duplicated().sum())
# Out:
# 0

# %%
import pandas as pd
import matplotlib.pyplot as plt

# อ่านข้อมูลจากไฟล์ CSV
df = pd.read_csv('province/data_eng_day.csv')

# ลบคอลัมน์ที่ไม่มีชื่อ (Unnamed)
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]

# แปลงคอลัมน์ timestamp ให้เป็นวันที่โดยเอาเวลาออก
df['timestamp'] = pd.to_datetime(df['timestamp'])

# ทำ differencing ในคอลัมน์ pm_10 และ humidity
df['pm_10_diff'] = df['pm_10'].diff()
df['humidity_diff'] = df['humidity'].diff()

# ตั้งค่าแกน x และ y สำหรับ differenced data
x = df['timestamp']
y_columns_diff = ['pm_10_diff', 'humidity_diff']

# พลอตกราฟเส้นที่มีจุดสำหรับ differenced data
plt.figure(figsize=(10, 6))
for column in y_columns_diff:
    plt.plot(x, df[column], marker='o', label=column)

# ตั้งค่าชื่อแกนและชื่อกราฟ
plt.xlabel('Date')
plt.ylabel('Differenced Values')
plt.title('Differenced Time Series Data')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()

# แสดงกราฟ
plt.show()

# แสดง DataFrame ที่มีคอลัมน์ differenced
print(df[['timestamp', 'pm_10_diff', 'humidity_diff']])
# Out:
#               timestamp  pm_10_diff  humidity_diff
# 0   2023-04-01 07:00:00         NaN            NaN
# 1   2023-04-03 07:00:00   11.319093      -5.989201
# 2   2023-04-04 07:00:00   -2.746227      -4.876541
# 3   2023-04-05 07:00:00   -1.435804      -3.513902
# 4   2023-04-06 07:00:00    4.541502       7.011523
# ..                  ...         ...            ...
# 658 2025-02-08 07:00:00   -4.089010      -1.585405
# 659 2025-02-09 07:00:00   -1.683184       0.567837
# 660 2025-02-10 07:00:00    1.681603       1.309951
# 661 2025-02-11 07:00:00    1.880287      -3.066711
# 662 2025-02-11 11:15:42    1.254801       8.170126
#
# [663 rows x 3 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# อ่านข้อมูลจากไฟล์ CSV
df = pd.read_csv('province/data_eng_day.csv')

# ลบคอลัมน์ที่ไม่มีชื่อ (Unnamed)
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]

# แปลงคอลัมน์ timestamp ให้เป็นวันที่โดยเอาเวลาออก
df['timestamp'] = pd.to_datetime(df['timestamp'])

# กำหนดเกณฑ์สำหรับค่า pm_10 และ humidity
df = df[(df['pm_10'] >= 0) & (df['pm_10'] <= 80)]
df = df[(df['humidity'] >= 0) & (df['humidity'] <= 100)]

# ทำ differencing ในคอลัมน์ pm_10, humidity, pm_2_5 และ temperature
df['pm_10_diff'] = df['pm_10'].diff()
df['humidity_diff'] = df['humidity'].diff()
df['pm_2_5_diff'] = df['pm_2_5'].diff()
df['temperature_diff'] = df['temperature'].diff()

# ตั้งค่าแกน x และ y สำหรับ differenced data
x = df['timestamp']
y_columns_diff = ['pm_10_diff', 'humidity_diff', 'pm_2_5_diff', 'temperature_diff']

# พลอตกราฟเส้นที่มีจุดสำหรับ differenced data
plt.figure(figsize=(10, 6))
for column in y_columns_diff:
    plt.plot(x, df[column], marker='o', label=column)

# ตั้งค่าชื่อแกนและชื่อกราฟ
plt.xlabel('Date')
plt.ylabel('Differenced Values')
plt.title('Differenced Time Series Data (Filtered)')
plt.legend()
plt.grid(True)
plt.xticks(rotation=45)
plt.tight_layout()

# แสดงกราฟ
plt.show()

# แสดง DataFrame ที่มีคอลัมน์ differenced
print(df[['timestamp', 'pm_10_diff', 'humidity_diff', 'pm_2_5_diff', 'temperature_diff']])
# Out:
#               timestamp  pm_10_diff  humidity_diff  pm_2_5_diff  \
# 0   2023-04-01 07:00:00         NaN            NaN          NaN
# 1   2023-04-03 07:00:00   11.319093      -5.989201     9.857940
# 2   2023-04-04 07:00:00   -2.746227      -4.876541    -2.647191
# 3   2023-04-05 07:00:00   -1.435804      -3.513902    -1.204456
# 4   2023-04-06 07:00:00    4.541502       7.011523     4.025294
# ..                  ...         ...            ...          ...
# 658 2025-02-08 07:00:00   -4.089010      -1.585405    -3.321219
# 659 2025-02-09 07:00:00   -1.683184       0.567837    -1.383102
# 660 2025-02-10 07:00:00    1.681603       1.309951     1.240083
# 661 2025-02-11 07:00:00    1.880287      -3.066711     1.665747
# 662 2025-02-11 11:15:42    1.254801       8.170126     2.065028
#
#      temperature_diff
# 0                 NaN
# 1           -0.294305
# 2            3.958258
# 3            1.918818
# 4           -3.909721
# ..                ...
# 658          0.113669
# 659         -0.011853
# 660         -0.122542
# 661          0.442598
# 662         -1.059933
#
# [662 rows x 5 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA

# อ่านข้อมูลจากไฟล์ CSV
df = pd.read_csv('province/data_eng_day.csv')

# ลบคอลัมน์ที่ไม่มีชื่อ (Unnamed)
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]

# แปลงคอลัมน์ timestamp ให้เป็นวันที่โดยเอาเวลาออก
df['timestamp'] = pd.to_datetime(df['timestamp'])

# กำหนดเกณฑ์สำหรับค่า pm_10 และ humidity
df = df[(df['pm_10'] >= 0) & (df['pm_10'] <= 80)]
df = df[(df['humidity'] >= 0) & (df['humidity'] <= 100)]

# ทำ differencing ในคอลัมน์ pm_10
df['pm_10_diff'] = df['pm_10'].diff().dropna()

# สร้างโมเดล ARIMA
model = ARIMA(df['pm_10_diff'].dropna(), order=(1, 1, 1))
model_fit = model.fit()

# สรุปผลการสร้างโมเดล
print(model_fit.summary())

# ทำนายค่าในอนาคต
forecast = model_fit.forecast(steps=10)
print(forecast)
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:             pm_10_diff   No. Observations:                  661
# Model:                 ARIMA(1, 1, 1)   Log Likelihood               -2314.359
# Date:                Thu, 27 Feb 2025   AIC                           4634.718
# Time:                        22:42:31   BIC                           4648.195
# Sample:                             0   HQIC                          4639.942
#                                 - 661
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.1667      0.033     -5.032      0.000      -0.232      -0.102
# ma.L1         -0.9996      0.234     -4.266      0.000      -1.459      -0.540
# sigma2        64.4114     15.454      4.168      0.000      34.123      94.700
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.36   Jarque-Bera (JB):                90.97
# Prob(Q):                              0.55   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.17   Skew:                             0.11
# Prob(H) (two-sided):                  0.23   Kurtosis:                         4.80
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# 661   -0.160982
# 662    0.075007
# 663    0.035671
# 664    0.042228
# 665    0.041135
# 666    0.041317
# 667    0.041287
# 668    0.041292
# 669    0.041291
# 670    0.041291
# Name: predicted_mean, dtype: float64
# /Users/pittachiox/Desktop/termproject/venv/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided. As a result, forecasts cannot be generated. To use the model for forecasting, use one of the supported classes of index.
#   self._init_dates(dates, freq)
# /Users/pittachiox/Desktop/termproject/venv/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided. As a result, forecasts cannot be generated. To use the model for forecasting, use one of the supported classes of index.
#   self._init_dates(dates, freq)
# /Users/pittachiox/Desktop/termproject/venv/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided. As a result, forecasts cannot be generated. To use the model for forecasting, use one of the supported classes of index.
#   self._init_dates(dates, freq)
# /Users/pittachiox/Desktop/termproject/venv/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /Users/pittachiox/Desktop/termproject/venv/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(

# %%
import pandas as pd
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA

# อ่านข้อมูลจากไฟล์ CSV
df = pd.read_csv('province/data_eng_day.csv')

# ลบคอลัมน์ที่ไม่มีชื่อ (Unnamed)
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]

# แปลงคอลัมน์ timestamp ให้เป็นวันที่โดยเอาเวลาออก
df['timestamp'] = pd.to_datetime(df['timestamp'])

# กำหนดเกณฑ์สำหรับค่า pm_10 และ humidity
df = df[(df['pm_10'] >= 0) & (df['pm_10'] <= 80)]
df = df[(df['humidity'] >= 0) & (df['humidity'] <= 100)]

# ทำ differencing ในคอลัมน์ pm_10
df['pm_10_diff'] = df['pm_10'].diff().dropna()

# สร้างโมเดล ARIMA ด้วยค่า order ที่ปรับใหม่
model = ARIMA(df['pm_10_diff'].dropna(), order=(2, 1, 2))
model_fit = model.fit()

# สรุปผลการสร้างโมเดล
print(model_fit.summary())

# ทำนายค่าในอนาคต
forecast = model_fit.forecast(steps=10)
print(forecast)
# Out:
# /Users/pittachiox/Desktop/termproject/venv/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided. As a result, forecasts cannot be generated. To use the model for forecasting, use one of the supported classes of index.
#   self._init_dates(dates, freq)
# /Users/pittachiox/Desktop/termproject/venv/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided. As a result, forecasts cannot be generated. To use the model for forecasting, use one of the supported classes of index.
#   self._init_dates(dates, freq)
# /Users/pittachiox/Desktop/termproject/venv/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:473: ValueWarning: An unsupported index was provided. As a result, forecasts cannot be generated. To use the model for forecasting, use one of the supported classes of index.
#   self._init_dates(dates, freq)
# /Users/pittachiox/Desktop/termproject/venv/lib/python3.10/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:             pm_10_diff   No. Observations:                  661
# Model:                 ARIMA(2, 1, 2)   Log Likelihood               -2277.932
# Date:                Thu, 27 Feb 2025   AIC                           4565.863
# Time:                        22:42:44   BIC                           4588.324
# Sample:                             0   HQIC                          4574.569
#                                 - 661
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.6419      0.040     15.958      0.000       0.563       0.721
# ar.L2         -0.0134      0.037     -0.367      0.714      -0.085       0.058
# ma.L1         -1.9371      0.052    -37.480      0.000      -2.038      -1.836
# ma.L2          0.9371      0.048     19.572      0.000       0.843       1.031
# sigma2        57.3160      4.577     12.522      0.000      48.345      66.287
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                91.73
# Prob(Q):                              0.99   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.22   Skew:                             0.36
# Prob(H) (two-sided):                  0.14   Kurtosis:                         4.68
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# 661   -0.795624
# 662   -0.522139
# 663   -0.319092
# 664   -0.192422
# 665   -0.113834
# 666   -0.065087
# 667   -0.034849
# 668   -0.016093
# 669   -0.004459
# 670    0.002758
# Name: predicted_mean, dtype: float64
# /Users/pittachiox/Desktop/termproject/venv/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:837: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(
# /Users/pittachiox/Desktop/termproject/venv/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:837: FutureWarning: No supported index is available. In the next version, calling this method in a model without a supported index will result in an exception.
#   return get_prediction_index(
